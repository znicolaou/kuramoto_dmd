# %%
import os
os.environ["OMP_NUM_THREADS"]='8'
import matplotlib.pyplot as plt
import numpy as np
from scipy.integrate import solve_ivp
import timeit
from scipy.special import erf
import multiprocessing
from IPython.display import Video,display

loadstr='module load cuda && '
def kuramoto(t, theta, omegas, sigma, adj):
    c=np.cos(theta)
    s=np.sin(theta)
    return omegas + sigma * (s*adj.dot(c)-c*adj.dot(s))

# %% [markdown]
# ## Dynamics for individual simulations

# %%
N=10000
K=10000
seed=1
c=1.75
t1=100
dt=1E-2
print('Store whole adjacency matrix with single precision')
os.system('bash -c "%s ./kuramoto -N %i -K %i -c %f -t %f -d %f -s %i -nv data/test"'%(loadstr,N,K,c,t1,dt,seed))
print('\nRecalculate adjacency elements each step with single precision')
os.system('bash -c "%s ./kuramoto -N %i -K %i -c %f -t %f -d %f -s %i -nvA data/testA"'%(loadstr,N,K,c,t1,dt,seed))
print('\nStore whole adjacency matrix with double precision')
os.system('bash -c "%s ./kuramoto_64 -N %i -K %i -c %f -t %f -d %f -s %i -nv data/test64"'%(loadstr,N,K,c,t1,dt,seed))
# Out:
# Store whole adjacency matrix with single precision
#
# Recalculate adjacency elements each step with single precision
#
# Store whole adjacency matrix with double precision
# ./kuramoto: error while loading shared libraries: libcuda.so.1: cannot open shared object file: No such file or directory
# ./kuramoto: error while loading shared libraries: libcuda.so.1: cannot open shared object file: No such file or directory
# ./kuramoto_64: error while loading shared libraries: libcuda.so.1: cannot open shared object file: No such file or directory
# 32512

# %%
filebase='data/test'
file=open(filebase+'.out')
lines=file.readlines()
N,K,t1,dt,c,seed=np.array(lines[0].split(),dtype=np.float64)
N=int(N)
K=int(K)
print(lines[1])
print(lines[-1])
file.close()

omega=np.fromfile(filebase+'frequencies.dat',dtype=np.float32)
N=len(omega)
thetas=np.unwrap(np.fromfile(filebase+'thetas.dat',dtype=np.float32).reshape((-1,N)),axis=0)
r=np.fromfile(filebase+'order.dat',dtype=np.float32)

plt.subplots(1,3,figsize=(12,3))
plt.subplot(1,3,1)
plt.plot(dt*np.arange(len(thetas)),thetas)
plt.xlabel('$t$')
plt.ylabel(r'$\theta_i$')

plt.subplot(1,3,2)
plt.plot(dt*np.arange(len(r)),r)
plt.xscale('log')
plt.yscale('log')
plt.xlabel('$t$')
plt.ylabel('$r$')

plt.subplot(1,3,3)
theta=np.fromfile(filebase+'fs.dat',dtype=np.float32)[:N]
order=np.argsort(omega)
plt.scatter(omega,np.mod(theta+np.pi,2*np.pi)-np.pi,s=1)
plt.xlim(np.median(omega)-5,np.median(omega)+5)
plt.xlabel('$\omega_i$')
plt.ylabel(r'$\theta_i$')

plt.tight_layout()
plt.show()
# Out:
# <>:34: SyntaxWarning: invalid escape sequence '\o'
# <>:34: SyntaxWarning: invalid escape sequence '\o'
# /tmp/ipykernel_1402802/371739100.py:34: SyntaxWarning: invalid escape sequence '\o'
#   plt.xlabel('$\omega_i$')
# ./kuramoto -N 10000 -K 10000 -c 1.750000 -t 100.000000 -d 0.010000 -s 1 -nv data/test
#
# runtime: 26.658391

# %%
filebase='data/testA'
file=open(filebase+'.out')
lines=file.readlines()
N,K,t1,dt,c,seed=np.array(lines[0].split(),dtype=np.float64)
N=int(N)
K=int(K)
print(lines[1])
print(lines[-1])
file.close()

omega=np.fromfile(filebase+'frequencies.dat',dtype=np.float32)
N=len(omega)
thetas=np.fromfile(filebase+'thetas.dat',dtype=np.float32).reshape((-1,N))
r=np.fromfile(filebase+'order.dat',dtype=np.float32)

plt.subplots(1,3,figsize=(12,3))
plt.subplot(1,3,1)
plt.plot(dt*np.arange(len(thetas)),thetas)
plt.xlabel('$t$')
plt.ylabel(r'$\theta_i$')

plt.subplot(1,3,2)
plt.plot(dt*np.arange(len(r)),r)
plt.xscale('log')
plt.yscale('log')
plt.xlabel('$t$')
plt.ylabel('$r$')

plt.subplot(1,3,3)
theta=np.fromfile(filebase+'fs.dat',dtype=np.float32)[:N]
order=np.argsort(omega)
plt.scatter(omega,np.mod(theta+np.pi,2*np.pi)-np.pi,s=1)
plt.xlim(np.median(omega)-5,np.median(omega)+5)
plt.xlabel('$\omega_i$')
plt.ylabel(r'$\theta_i$')

plt.tight_layout()
plt.show()
# Out:
# <>:34: SyntaxWarning: invalid escape sequence '\o'
# <>:34: SyntaxWarning: invalid escape sequence '\o'
# /tmp/ipykernel_1402802/832363079.py:34: SyntaxWarning: invalid escape sequence '\o'
#   plt.xlabel('$\omega_i$')
# ./kuramoto -N 10000 -K 10000 -c 1.750000 -t 100.000000 -d 0.010000 -s 1 -nvA data/testA
#
# runtime: 101.177718

# %%
filebase='data/test64'
file=open(filebase+'.out')
lines=file.readlines()
N,K,t1,dt,c,seed=np.array(lines[0].split(),dtype=np.float64)
N=int(N)
K=int(K)
print(lines[1])
print(lines[-1])
file.close()

omega=np.fromfile(filebase+'frequencies.dat',dtype=np.float64)
N=len(omega)
thetas=np.fromfile(filebase+'thetas.dat',dtype=np.float64).reshape((-1,N))
r=np.fromfile(filebase+'order.dat',dtype=np.float64)

plt.subplots(1,3,figsize=(12,3))
plt.subplot(1,3,1)
plt.plot(dt*np.arange(len(thetas)),thetas)
plt.xlabel('$t$')
plt.ylabel(r'$\theta_i$')

plt.subplot(1,3,2)
plt.plot(dt*np.arange(len(r)),r)
plt.xscale('log')
plt.yscale('log')
plt.xlabel('$t$')
plt.ylabel('$r$')

plt.subplot(1,3,3)
theta=np.fromfile(filebase+'fs.dat',dtype=np.float64)[:N]
order=np.argsort(omega)
plt.scatter(omega,np.mod(theta+np.pi,2*np.pi)-np.pi,s=1)
plt.xlim(np.median(omega)-5,np.median(omega)+5)
plt.xlabel('$\omega_i$')
plt.ylabel(r'$\theta_i$')

plt.tight_layout()
plt.show()
# Out:
# <>:34: SyntaxWarning: invalid escape sequence '\o'
# <>:34: SyntaxWarning: invalid escape sequence '\o'
# /tmp/ipykernel_1402802/796916189.py:34: SyntaxWarning: invalid escape sequence '\o'
#   plt.xlabel('$\omega_i$')
# ./kuramoto_64 -N 10000 -K 10000 -c 1.750000 -t 100.000000 -d 0.010000 -s 1 -nv data/test64
#
# runtime: 53.481288

# %% [markdown]
# ### Animate a simulation

# %%
N=100000
K=100000
seed=1
c=3
t1=20
dt=2E-2

os.system('bash -c "%s ./kuramoto -N %i -K %i -c %f -t %f -d %f -s %i -D1 -nvA data/testbig"'%(loadstr,N,K,c,t1,dt,seed))
# Out:
# GPU Memory: 47434694656 47729344512 40000000
# Using random initial conditions
# Using random frequencies
# Using random adjacency matrix
# 1.005	3.593e+02	-1.650e+00	0.095268	231
# runtime: 359.541972
# 0

# %%
filebase='data/testbig'
file=open(filebase+'.out')
lines=file.readlines()
N,K,t1,dt,c,seed=np.array(lines[0].split(),dtype=np.float64)
N=int(N)
K=int(K)
print(lines[1])
print(lines[-1])
file.close()

omega=np.fromfile(filebase+'frequencies.dat',dtype=np.float32)
N=len(omega)
thetas=np.fromfile(filebase+'thetas.dat',dtype=np.float32).reshape((-1,N))
r=np.fromfile(filebase+'order.dat',dtype=np.float32)

def makeplot(n, save=True, show=False):
    plt.subplots(1,2,figsize=(8,3))
    plt.subplot(1,2,1)
    plt.plot(dt*np.arange(len(r)),r,lw=1,c='gray')
    plt.plot(dt*np.arange(n),r[:n],lw=2)
    plt.xscale('log')
    plt.yscale('log')
    plt.xlabel('$t$')
    plt.ylabel('$r$')

    plt.subplot(1,2,2)
    theta=np.fromfile(filebase+'fs.dat',dtype=np.float32)[:N]
    order=np.argsort(omega)
    plt.scatter(omega,np.mod(thetas[n]+np.pi,2*np.pi)-np.pi,s=0.1,alpha=0.1)
    plt.xlim(np.median(omega)-5,np.median(omega)+5)
    plt.ylim(-np.pi,np.pi)
    plt.xlabel('$\omega_i$')
    plt.ylabel(r'$\theta_i$')

    plt.tight_layout()
    if save:
        plt.savefig(filebase+'animation/%04i.png'%n,dpi=200)
    if show:
        plt.show()
    plt.close()

print(len(thetas))
makeplot(0,show=True,save=False)
makeplot(len(thetas)-1,show=True,save=False)
# Out:
# <>:32: SyntaxWarning: invalid escape sequence '\o'
# <>:32: SyntaxWarning: invalid escape sequence '\o'
# /tmp/ipykernel_1540904/914824297.py:32: SyntaxWarning: invalid escape sequence '\o'
#   plt.xlabel('$\omega_i$')
# ./kuramoto -N 100000 -K 100000 -c 3.000000 -t 20.000000 -d 0.020000 -s 1 -D1 -nvA data/testbig
#
# runtime: 359.541972
#
# 1001

# %%
if not os.path.exists(filebase+'animation'):
    os.mkdir(filebase+'animation')
else:
    os.system('rm %sanimation/*'%(filebase))

nt=len(thetas)
start=timeit.default_timer()
pool = multiprocessing.Pool(8,maxtasksperchild=1)
pool.map(makeplot, range(nt))
pool.close()
stop=timeit.default_timer()
print(stop-start)

os.system('encode.sh %sanimation %sanimation 30'%(filebase, filebase))

display(Video('%sanimation.mp4'%(filebase),width=512))
# Out:
# 125.66132313758135
# ffmpeg version 6.1.1 Copyright (c) 2000-2023 the FFmpeg developers
#   built with gcc 11.2.0 (Anaconda gcc)
#   configuration: --prefix=/nfs/home/znicolao/.conda/envs/my_env --cc=/home/task_175975072617190/conda-bld/ffmpeg_1759751615537/_build_env/bin/x86_64-conda-linux-gnu-cc --ar=/home/task_175975072617190/conda-bld/ffmpeg_1759751615537/_build_env/bin/x86_64-conda-linux-gnu-ar --nm=/home/task_175975072617190/conda-bld/ffmpeg_1759751615537/_build_env/bin/x86_64-conda-linux-gnu-nm --ranlib=/home/task_175975072617190/conda-bld/ffmpeg_1759751615537/_build_env/bin/x86_64-conda-linux-gnu-ranlib --strip=/home/task_175975072617190/conda-bld/ffmpeg_1759751615537/_build_env/bin/x86_64-conda-linux-gnu-strip --disable-doc --enable-swresample --enable-swscale --enable-openssl --enable-libxml2 --enable-libtheora --enable-demuxer=dash --enable-postproc --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libdav1d --enable-zlib --enable-libaom --enable-pic --enable-shared --disable-static --disable-gpl --enable-version3 --disable-sdl2 --enable-libopenh264 --enable-libopus --enable-libmp3lame --enable-libopenjpeg --enable-libvorbis --enable-pthreads --enable-libtesseract --enable-libvpx
#   libavutil      58. 29.100 / 58. 29.100
#   libavcodec     60. 31.102 / 60. 31.102
#   libavformat    60. 16.100 / 60. 16.100
#   libavdevice    60.  3.100 / 60.  3.100
#   libavfilter     9. 12.100 /  9. 12.100
#   libswscale      7.  5.100 /  7.  5.100
#   libswresample   4. 12.100 /  4. 12.100
# Input #0, image2, from 'data/testbiganimation/%04d.png':
#   Duration: 00:00:40.04, start: 0.000000, bitrate: N/A
#   Stream #0:0: Video: png, rgba(pc, gbr/unknown/unknown), 1600x600 [SAR 7874:7874 DAR 8:3], 25 fps, 25 tbr, 25 tbn
# [out#0/mp4 @ 0x766600] Codec AVOption crf (Select the quality for constant quality mode) has not been used for any stream. The most likely reason is either wrong type (e.g. a video option with no video streams) or that it is a private option of some encoder which was not actually used for any stream.
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libopenh264))
# Press [q] to stop, [?] for help
# [libopenh264 @ 0x768240] [OpenH264] this = 0x0xc90410, Warning:layerId(0) doesn't support profile(578), change to UNSPECIFIC profile
# [libopenh264 @ 0x768240] [OpenH264] this = 0x0xc90410, Warning:bEnableFrameSkip = 0,bitrate can't be controlled for RC_QUALITY_MODE,RC_BITRATE_MODE and RC_TIMESTAMP_MODE without enabling skip frame.
# Output #0, mp4, to 'data/testbiganimation.mp4':
#   Metadata:
#     encoder         : Lavf60.16.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuv420p(tv, progressive), 1600x600 [SAR 1:1 DAR 8:3], q=2-31, 30 fps, 15360 tbn
#     Metadata:
#       encoder         : Lavc60.31.102 libopenh264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/2000000 buffer size: 0 vbv_delay: N/A
# [out#0/mp4 @ 0x766600] video:8001kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.059805%
# frame= 1001 fps= 83 q=-0.0 Lsize=    8006kB time=00:00:33.33 bitrate=1967.6kbits/s speed=2.75x
# <video src="data/testbiganimation.mp4" controls  width="512" >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
N=100000
K=6
seed=1
c=3
t1=20
dt=2E-2
os.system('bash -c "%s ./kuramoto -N %i -K %i -c %f -t %f -d %f -s %i -D1 -nvA data/testbig2"'%(loadstr,N,K,c,t1,dt,seed))
# Out:
# GPU Memory: 47434694656 47729344512 40000000
# Using random initial conditions
# Using random frequencies
# Using random adjacency matrix
# 1.008	1.618e+01	-1.297e-01	0.164481	120
# runtime: 16.209220
# 0

# %%
filebase='data/testbig2'
file=open(filebase+'.out')
lines=file.readlines()
N,K,t1,dt,c,seed=np.array(lines[0].split(),dtype=np.float64)
N=int(N)
K=int(K)
print(lines[1])
print(lines[-1])
file.close()

omega=np.fromfile(filebase+'frequencies.dat',dtype=np.float32)
N=len(omega)
thetas=np.fromfile(filebase+'thetas.dat',dtype=np.float32).reshape((-1,N))
r=np.fromfile(filebase+'order.dat',dtype=np.float32)

def makeplot(n, save=True, show=False):
    plt.subplots(1,2,figsize=(8,3))
    plt.subplot(1,2,1)
    plt.plot(dt*np.arange(len(r)),r,lw=1,c='gray')
    plt.plot(dt*np.arange(n),r[:n],lw=2)
    plt.xscale('log')
    plt.yscale('log')
    plt.xlabel('$t$')
    plt.ylabel('$r$')

    plt.subplot(1,2,2)
    theta=np.fromfile(filebase+'fs.dat',dtype=np.float32)[:N]
    order=np.argsort(omega)
    plt.scatter(omega,np.mod(thetas[n]+np.pi,2*np.pi)-np.pi,s=0.1,alpha=0.1)
    plt.xlim(np.median(omega)-5,np.median(omega)+5)
    plt.ylim(-np.pi,np.pi)
    plt.xlabel('$\omega_i$')
    plt.ylabel(r'$\theta_i$')

    plt.tight_layout()
    if save:
        plt.savefig(filebase+'animation/%04i.png'%n,dpi=200)
    if show:
        plt.show()
    plt.close()

print(len(thetas))
makeplot(0,show=True,save=False)
makeplot(len(thetas)-1,show=True,save=False)
# Out:
# <>:32: SyntaxWarning: invalid escape sequence '\o'
# <>:32: SyntaxWarning: invalid escape sequence '\o'
# /tmp/ipykernel_1540904/2754623593.py:32: SyntaxWarning: invalid escape sequence '\o'
#   plt.xlabel('$\omega_i$')
# ./kuramoto -N 100000 -K 6 -c 3.000000 -t 20.000000 -d 0.020000 -s 1 -D1 -nvA data/testbig2
#
# runtime: 16.209220
#
# 1001

# %%
if not os.path.exists(filebase+'animation'):
    os.mkdir(filebase+'animation')
else:
    os.system('rm %sanimation/*'%(filebase))

nt=len(thetas)
start=timeit.default_timer()
pool = multiprocessing.Pool(8,maxtasksperchild=1)
pool.map(makeplot, range(nt))
pool.close()
stop=timeit.default_timer()
print(stop-start)

os.system('encode.sh %sanimation %sanimation 30'%(filebase, filebase))

display(Video('%sanimation.mp4'%(filebase),width=512))
# Out:
# 125.9630080126226
# ffmpeg version 6.1.1 Copyright (c) 2000-2023 the FFmpeg developers
#   built with gcc 11.2.0 (Anaconda gcc)
#   configuration: --prefix=/nfs/home/znicolao/.conda/envs/my_env --cc=/home/task_175975072617190/conda-bld/ffmpeg_1759751615537/_build_env/bin/x86_64-conda-linux-gnu-cc --ar=/home/task_175975072617190/conda-bld/ffmpeg_1759751615537/_build_env/bin/x86_64-conda-linux-gnu-ar --nm=/home/task_175975072617190/conda-bld/ffmpeg_1759751615537/_build_env/bin/x86_64-conda-linux-gnu-nm --ranlib=/home/task_175975072617190/conda-bld/ffmpeg_1759751615537/_build_env/bin/x86_64-conda-linux-gnu-ranlib --strip=/home/task_175975072617190/conda-bld/ffmpeg_1759751615537/_build_env/bin/x86_64-conda-linux-gnu-strip --disable-doc --enable-swresample --enable-swscale --enable-openssl --enable-libxml2 --enable-libtheora --enable-demuxer=dash --enable-postproc --enable-hardcoded-tables --enable-libfreetype --enable-libharfbuzz --enable-libfontconfig --enable-libdav1d --enable-zlib --enable-libaom --enable-pic --enable-shared --disable-static --disable-gpl --enable-version3 --disable-sdl2 --enable-libopenh264 --enable-libopus --enable-libmp3lame --enable-libopenjpeg --enable-libvorbis --enable-pthreads --enable-libtesseract --enable-libvpx
#   libavutil      58. 29.100 / 58. 29.100
#   libavcodec     60. 31.102 / 60. 31.102
#   libavformat    60. 16.100 / 60. 16.100
#   libavdevice    60.  3.100 / 60.  3.100
#   libavfilter     9. 12.100 /  9. 12.100
#   libswscale      7.  5.100 /  7.  5.100
#   libswresample   4. 12.100 /  4. 12.100
# Input #0, image2, from 'data/testbig2animation/%04d.png':
#   Duration: 00:00:40.04, start: 0.000000, bitrate: N/A
#   Stream #0:0: Video: png, rgba(pc, gbr/unknown/unknown), 1600x600 [SAR 7874:7874 DAR 8:3], 25 fps, 25 tbr, 25 tbn
# [out#0/mp4 @ 0x662600] Codec AVOption crf (Select the quality for constant quality mode) has not been used for any stream. The most likely reason is either wrong type (e.g. a video option with no video streams) or that it is a private option of some encoder which was not actually used for any stream.
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libopenh264))
# Press [q] to stop, [?] for help
# [libopenh264 @ 0x664240] [OpenH264] this = 0x0x1304890, Warning:layerId(0) doesn't support profile(578), change to UNSPECIFIC profile
# [libopenh264 @ 0x664240] [OpenH264] this = 0x0x1304890, Warning:bEnableFrameSkip = 0,bitrate can't be controlled for RC_QUALITY_MODE,RC_BITRATE_MODE and RC_TIMESTAMP_MODE without enabling skip frame.
# Output #0, mp4, to 'data/testbig2animation.mp4':
#   Metadata:
#     encoder         : Lavf60.16.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuv420p(tv, progressive), 1600x600 [SAR 1:1 DAR 8:3], q=2-31, 30 fps, 15360 tbn
#     Metadata:
#       encoder         : Lavc60.31.102 libopenh264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/2000000 buffer size: 0 vbv_delay: N/A
# [out#0/mp4 @ 0x662600] video:6196kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.077737%
# frame= 1001 fps= 87 q=-0.0 Lsize=    6201kB time=00:00:33.33 bitrate=1523.9kbits/s speed= 2.9x
# <video src="data/testbig2animation.mp4" controls  width="512" >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %% [markdown]
# ### Order parameter averaged over 750 seeds, as in Ottino and Strogatz

# %%
N=5000
Ks=[5000,2]
dt=0.1

plt.subplots(1,2,figsize=(7,3))

for K in Ks:
    plt.subplot(1,2,1)
    r=np.load('data/lorentz/%i/%i/avgorder.npy'%(N,K))
    plt.plot(dt*np.arange(len(r)),r,label='K=$%i$'%K)
    plt.plot(dt*np.arange(len(r)),(np.pi/4)**0.5/(N**0.5)*np.ones(len(r)),ls='--',c='black')
    plt.gca().legend(bbox_to_anchor=(1, 1.2),ncol=2)
    plt.ylabel('$r$')
    plt.xlabel(r'$t$')
    plt.xscale('log')
    plt.yscale('log')

    plt.subplot(1,2,2)
    filebase='data/lorentz/%i/%i/%i'%(N,K,1)
    omega=np.fromfile(filebase+'frequencies.dat',np.float32)
    theta=np.mod(np.fromfile(filebase+'fs.dat',dtype=np.float32)[:N]+np.pi,2*np.pi)-np.pi
    plt.scatter(omega-np.median(omega),theta,s=1,label='K=$%i$'%K)
    plt.xlabel('$\omega_i$')
    plt.ylabel(r'$\theta_i$')
    
plt.gca().legend(bbox_to_anchor=(1, 1.2),ncol=2)

plt.xlim(-3,3)
plt.xlabel('$\omega_i-\omega_{N/2}$')
plt.ylabel(r'$\theta_i$')

plt.tight_layout()
plt.savefig('5000lorentz.pdf')
plt.show()
# Out:
# <>:23: SyntaxWarning: invalid escape sequence '\o'
# <>:29: SyntaxWarning: invalid escape sequence '\o'
# <>:23: SyntaxWarning: invalid escape sequence '\o'
# <>:29: SyntaxWarning: invalid escape sequence '\o'
# /tmp/ipykernel_1616876/2036480317.py:23: SyntaxWarning: invalid escape sequence '\o'
#   plt.xlabel('$\omega_i$')
# /tmp/ipykernel_1616876/2036480317.py:29: SyntaxWarning: invalid escape sequence '\o'
#   plt.xlabel('$\omega_i-\omega_{N/2}$')

# %% [markdown]
# ### Order parameter averaged over 750 seeds, for normally distributed frequencies

# %%
N=5000
Ks=[5000,2]
dt=0.1

plt.subplots(1,2,figsize=(6,3))

for K in Ks:
    plt.subplot(1,2,1)
    r=np.load('data/normal/%i/%i/avgorder.npy'%(N,K))
    plt.plot(dt*np.arange(len(r)),r,label='K=$%i$'%K)
    plt.plot(dt*np.arange(len(r)),(np.pi/4)**0.5/(N**0.5)*np.ones(len(r)),ls='--',c='black')
    plt.gca().legend(bbox_to_anchor=(1, 1.2),ncol=2)
    plt.ylabel('$r$')
    plt.xlabel(r'$t$')
    plt.xscale('log')
    plt.yscale('log')

    plt.subplot(1,2,2)
    filebase='data/normal/%i/%i/%i'%(N,K,1)
    omega=np.fromfile(filebase+'frequencies.dat',np.float32)
    theta=np.mod(np.fromfile(filebase+'fs.dat',np.float32)+np.pi,2*np.pi)[:N]-np.pi
    plt.scatter(omega-np.median(omega),theta,s=1,label='K=$%i$'%K)
    plt.xlabel('$\omega_i$')
    plt.ylabel(r'$\theta_i$')

plt.gca().legend(bbox_to_anchor=(1, 1.2),ncol=2)

plt.xlim(-3,3)
plt.xlabel('$\omega_i-\omega_{N/2}$')
plt.ylabel(r'$\theta_i$')

plt.tight_layout()
plt.savefig('5000normal.pdf')
plt.show()
# Out:
# <>:23: SyntaxWarning: invalid escape sequence '\o'
# <>:29: SyntaxWarning: invalid escape sequence '\o'
# <>:23: SyntaxWarning: invalid escape sequence '\o'
# <>:29: SyntaxWarning: invalid escape sequence '\o'
# /tmp/ipykernel_1616876/726066393.py:23: SyntaxWarning: invalid escape sequence '\o'
#   plt.xlabel('$\omega_i$')
# /tmp/ipykernel_1616876/726066393.py:29: SyntaxWarning: invalid escape sequence '\o'
#   plt.xlabel('$\omega_i-\omega_{N/2}$')

# %% [markdown]
# ### Order parameter averaged over 500 seeds, for normally distributed frequencies with much larger N

# %%
dt=0.01
seed=1
seeds=500
rows=101

Ns=[10000, 20000, 100000, 200000]
fig,ax=plt.subplots(2,4,figsize=(12,6))

ind=1
for N in Ns:
    Ks=[0,2*N//10,4*N//10,6*N//10,8*N//10,N]
        
    plt.subplot(2,4,ind)
    for K in Ks:
        if os.path.exists('data/normal/%i/%i/avgorder.npy'%(N,K)):
            plt.plot(dt*np.arange(10001),np.load('data/normal/%i/%i/avgorder.npy'%(N,K)),label='K/N=%.1f'%(K/N))
            plt.yscale('log')
            plt.xscale('log',base=10,subs=np.arange(10))
#             plt.xlabel('$t$')
            plt.gca().set_xticklabels([])
            if ind==1:
                plt.ylabel('$r$')
            else:
                plt.gca().set_yticklabels([])
            plt.ylim(1E-3,2E0)

    plt.plot(dt*np.arange(10001),(np.pi/4)**0.5/(N**0.5)*np.ones(10001),ls='--',c='black')
    plt.title('$N=%i$'%N)
    ind=ind+1

    
for N in Ns:
    Ks=[0,2*N//10,4*N//10,6*N//10,8*N//10,N]
        
    plt.subplot(2,4,ind)
    for K in Ks:
        if os.path.exists('data/scaled/%i/%i/avgorder.npy'%(N,K)):
            plt.plot(dt*np.arange(10001),np.load('data/scaled/%i/%i/avgorder.npy'%(N,K)),label='K/N=%.1f'%(K/N))
            plt.yscale('log')
            plt.xscale('log',base=10,subs=np.arange(10))
            plt.xlabel('$t$')
            if ind==5:
                plt.ylabel('$r$')
            else:
                plt.gca().set_yticklabels([])
            plt.ylim(1E-3,2E0)

    plt.plot(dt*np.arange(10001),(np.pi/4)**0.5/(N**0.5)*np.ones(10001),ls='--',c='black')
#     plt.title('$N=%i$'%N)
    ind=ind+1


    
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')

plt.tight_layout()
plt.savefig('orders_2.pdf')
plt.show()

# %% [markdown]
# ### Benchmark against solve_ivp

# %%
np.random.seed(1)
N=10000
K=10000
omega=np.fromfile('data/test64frequencies.dat')
adj=np.fromfile('data/test64adj.dat').reshape((N,N))

sigma=1.75
t1=100
dt=0.01
dt1=dt/1000

theta=np.zeros(N)

start=timeit.default_timer()
sol=solve_ivp(kuramoto, [0, t1], theta, rtol=0, atol=1E-6, args=(omega, sigma, adj), dense_output=True, method='RK45')
stop=timeit.default_timer()
print("runtime: %f"%(stop-start))

t=dt*np.arange(10001)
thetas=sol.sol(t).T
r=np.abs(np.mean(np.exp(1j*thetas),axis=1))


plt.subplots(1,3,figsize=(12,3))
plt.subplot(1,3,1)
plt.plot(dt*np.arange(len(thetas)),thetas)
plt.xlabel('$t$')
plt.ylabel(r'$\theta_i$')

plt.subplot(1,3,2)
plt.plot(dt*np.arange(len(r)),r)
plt.xscale('log')
plt.yscale('log')
plt.xlabel('$t$')
plt.ylabel('$r$')

plt.subplot(1,3,3)
order=np.argsort(omega)
plt.scatter(omega,np.mod(thetas[-1]+np.pi,2*np.pi)-np.pi,s=1)
plt.xlim(np.median(omega)-5,np.median(omega)+5)
plt.xlabel('$\omega_i$')
plt.ylabel(r'$\theta_i$')

plt.tight_layout()
plt.show()
# Out:
# <>:41: SyntaxWarning: invalid escape sequence '\o'
# <>:41: SyntaxWarning: invalid escape sequence '\o'
# /tmp/ipykernel_1540904/340267359.py:41: SyntaxWarning: invalid escape sequence '\o'
#   plt.xlabel('$\omega_i$')
# /nfs/home/znicolao/.conda/envs/my_env/lib/python3.13/site-packages/scipy/integrate/_ivp/ivp.py:621: UserWarning: At least one element of `rtol` is too small. Setting `rtol = np.maximum(rtol, 2.220446049250313e-14)`.
#   solver = method(fun, t0, y0, tf, vectorized=vectorized, **options)
# runtime: 71.654954

# %%
filebase='data/test'
file=open(filebase+'.out')
lines=file.readlines()
N,K,t1,dt,c,seed=np.array(lines[0].split(),dtype=np.float64)
N=int(N)
K=int(K)
print(lines[1])
print(lines[-1])
file.close()

plt.plot(sol.t[:-1],np.diff(sol.t),label='scipy')
plt.plot(np.fromfile(filebase+'times.dat',dtype=np.float32)[:-1],np.diff(np.fromfile(filebase+'times.dat',dtype=np.float32)),label='32bit gpu')
plt.legend()
plt.xlabel('$t$')
plt.ylabel('$dt$')
plt.show()

plt.plot(t,thetas-np.fromfile(filebase+'thetas.dat',dtype=np.float32).reshape((-1,N)))
plt.xlabel('$t$')
plt.ylabel(r'$\Delta\theta_i$')
plt.show()
# Out:
# ./kuramoto -N 10000 -K 10000 -c 1.750000 -t 100.000000 -d 0.010000 -s 1 -nv data/test
#
# runtime: 26.658391

# %%
filebase='data/testA'
file=open(filebase+'.out')
lines=file.readlines()
N,K,t1,dt,c,seed=np.array(lines[0].split(),dtype=np.float64)
N=int(N)
K=int(K)
print(lines[1])
print(lines[-1])
file.close()

plt.plot(sol.t[:-1],np.diff(sol.t),label='scipy')
plt.plot(np.fromfile(filebase+'times.dat',dtype=np.float32)[:-1],np.diff(np.fromfile(filebase+'times.dat',dtype=np.float32)),label='32bit gpu')
plt.legend()
plt.xlabel('$t$')
plt.ylabel('$dt$')
plt.show()

plt.plot(t,thetas-np.fromfile(filebase+'thetas.dat',dtype=np.float32).reshape((-1,N)))
plt.xlabel('$t$')
plt.ylabel(r'$\Delta\theta_i$')
plt.show()
# Out:
# ./kuramoto -N 10000 -K 10000 -c 1.750000 -t 100.000000 -d 0.010000 -s 1 -nvA data/testA
#
# runtime: 101.177718

# %%
filebase='data/test64'
file=open(filebase+'.out')
lines=file.readlines()
N,K,t1,dt,c,seed=np.array(lines[0].split(),dtype=np.float64)
N=int(N)
K=int(K)
print(lines[1])
print(lines[-1])
file.close()

plt.plot(sol.t[:-1],np.diff(sol.t),label='scipy')
plt.plot(np.fromfile(filebase+'times.dat',dtype=np.float64)[:-1],np.diff(np.fromfile(filebase+'times.dat',dtype=np.float64)),label='64bit gpu')
plt.legend()
plt.xlabel('$t$')
plt.ylabel('$dt$')
plt.show()

plt.plot(t,thetas-np.fromfile(filebase+'thetas.dat',dtype=np.float64).reshape((-1,N)))
plt.xlabel('$t$')
plt.ylabel(r'$\Delta\theta_i$')
plt.show()
# Out:
# ./kuramoto_64 -N 10000 -K 10000 -c 1.750000 -t 100.000000 -d 0.010000 -s 1 -nv data/test64
#
# runtime: 53.481288

# %% [markdown]
# ### Coupling field plots, as in Strogatz and Ottino

# %%
N=5000
K=6
c=1.75
t1=10000
dt=0.1
seed=1
filebase='data/newtest1'
print('Store whole adjacency matrix with single precision')
if os.path.exists(filebase+'.out'):
    os.remove(filebase+'.out')
os.system('bash -c " %s ./kuramoto -g 3 -N %i -K %i -c %f -t %f -d %f -s %i -nv %s"'%(loadstr,N,K,c,0,dt,seed,filebase))
os.system('bash -c " %s ./kuramoto -g 3 -N %i -K %i -c %f -t %f -d %f -s %i -nDv %s"'%(loadstr,N,K,c,t1,dt,seed,filebase))
# Out:
# Store whole adjacency matrix with single precision
# GPU Memory: 47434694656 47729344512 102240000
# Using random initial conditions
# Using random frequencies
# Using random adjacency matrix
#
# runtime: 0.704227
# GPU Memory: 47434694656 47729344512 102240000
# Using random initial conditions
# Using random frequencies
# Using random adjacency matrix
#
# runtime: 284.600628
# 0

# %%
N=5000
K=6
c=1.0
t1=10000
dt=0.1
seed=1
filebase='data/newtest2'
print('Store whole adjacency matrix with single precision')
if os.path.exists(filebase+'.out'):
    os.remove(filebase+'.out')
os.system('bash -c " %s ./kuramoto -g 3 -N %i -K %i -c %f -t %f -d %f -s %i -nv %s"'%(loadstr,N,K,c,0,dt,seed,filebase))
os.system('bash -c " %s ./kuramoto -g 3 -N %i -K %i -c %f -t %f -d %f -s %i -nDv %s"'%(loadstr,N,K,c,t1,dt,seed,filebase))
# Out:
# Store whole adjacency matrix with single precision
# GPU Memory: 47434694656 47729344512 102240000
# Using random initial conditions
# Using random frequencies
# Using random adjacency matrix
#
# runtime: 0.457648
# GPU Memory: 47434694656 47729344512 102240000
# Using random initial conditions
# Using random frequencies
# Using random adjacency matrix
#
# runtime: 68.505410
# 0

# %%
N=5000
K=5000
c=1.0
t1=10000
dt=0.1
seed=1
filebase='data/newtest3'
print('Store whole adjacency matrix with single precision')
if os.path.exists(filebase+'.out'):
    os.remove(filebase+'.out')
os.system('bash -c " %s ./kuramoto -g 3 -N %i -K %i -c %f -t %f -d %f -s %i -nv %s"'%(loadstr,N,K,c,0,dt,seed,filebase))
os.system('bash -c " %s ./kuramoto -g 3 -N %i -K %i -c %f -t %f -d %f -s %i -nDv %s"'%(loadstr,N,K,c,t1,dt,seed,filebase))
# Out:
# Store whole adjacency matrix with single precision
# GPU Memory: 47434694656 47729344512 302000000
# Using random initial conditions
# Using random frequencies
# Using random adjacency matrix
#
# runtime: 1.385846

# %%
N=5000
K=5000
c=3
t1=10000
dt=0.1
seed=1
filebase='data/newtest4'
print('Store whole adjacency matrix with single precision')
if os.path.exists(filebase+'.out'):
    os.remove(filebase+'.out')
os.system('bash -c " %s ./kuramoto -g 3 -N %i -K %i -c %f -t %f -d %f -s %i -nv %s"'%(loadstr,N,K,c,0,dt,seed,filebase))
os.system('bash -c " %s ./kuramoto -g 3 -N %i -K %i -c %f -t %f -d %f -s %i -nDv %s"'%(loadstr,N,K,c,t1,dt,seed,filebase))

# %%
filebase='data/newtest1'
file=open(filebase+'.out')
lines=file.readlines()
N,K,t1,dt,c,seed=np.array(lines[0].split(),dtype=np.float64)
N=int(N)
K=int(K)
print(lines[1])
print(lines[-1])
file.close()

omega=np.fromfile(filebase+'frequencies.dat',dtype=np.float32)
N=len(omega)
thetas=np.unwrap(np.fromfile(filebase+'thetas.dat',dtype=np.float32).reshape((-1,N)),axis=0)
theta=np.fromfile(filebase+'fs.dat',dtype=np.float32)[:N]
r=np.fromfile(filebase+'order.dat',dtype=np.float32)
adj=np.fromfile(filebase+'adj.dat',dtype=np.float32).reshape((N,N))
coupling=np.fromfile(filebase+'fs.dat',dtype=np.float32)[N+2:]
B=np.mod(theta[:,np.newaxis]-np.arctan2(coupling[1::2],coupling[::2])[np.newaxis,:]+np.pi,2*np.pi)-np.pi


plt.subplots(1,3,figsize=(12,3))
plt.subplot(1,3,1)
plt.hist2d(N/2*adj.reshape(-1),B.reshape(-1),bins=(np.arange(10)-5+0.5,np.pi*(np.arange(100)-50+0.5)/50),density=True)
plt.xlabel(r'$NJ_{jk}/J$')
plt.ylabel(r'$\theta_j-\phi_k$')
plt.colorbar()

plt.subplot(1,3,2)
plt.plot(dt*np.arange(len(r)),r)
plt.xscale('log')
plt.yscale('log')
plt.xlabel('$t$')
plt.ylabel('$r$')

plt.subplot(1,3,3)
order=np.argsort(omega)
plt.scatter(omega,np.mod(theta+np.pi,2*np.pi)-np.pi,s=1)
plt.xlim(np.median(omega)-5,np.median(omega)+5)
plt.xlabel('$\omega_i$')
plt.ylabel(r'$\theta_i$')

plt.tight_layout()
plt.show()
# Out:
# <>:39: SyntaxWarning: invalid escape sequence '\o'
# <>:39: SyntaxWarning: invalid escape sequence '\o'
# /tmp/ipykernel_1616876/303294436.py:39: SyntaxWarning: invalid escape sequence '\o'
#   plt.xlabel('$\omega_i$')
# ./kuramoto -g 3 -N 5000 -K 6 -c 1.750000 -t 0.000000 -d 0.100000 -s 1 -nv data/newtest1
#
# runtime: 284.600628

# %%
filebase='data/newtest2'
file=open(filebase+'.out')
lines=file.readlines()
N,K,t1,dt,c,seed=np.array(lines[0].split(),dtype=np.float64)
N=int(N)
K=int(K)
print(lines[1])
print(lines[-1])
file.close()

omega=np.fromfile(filebase+'frequencies.dat',dtype=np.float32)
N=len(omega)
thetas=np.unwrap(np.fromfile(filebase+'thetas.dat',dtype=np.float32).reshape((-1,N)),axis=0)
theta=np.fromfile(filebase+'fs.dat',dtype=np.float32)[:N]
r=np.fromfile(filebase+'order.dat',dtype=np.float32)
adj=np.fromfile(filebase+'adj.dat',dtype=np.float32).reshape((N,N))
coupling=np.fromfile(filebase+'fs.dat',dtype=np.float32)[N+2:]
B=np.mod(theta[:,np.newaxis]-np.arctan2(coupling[1::2],coupling[::2])[np.newaxis,:]+np.pi,2*np.pi)-np.pi


plt.subplots(1,3,figsize=(12,3))
plt.subplot(1,3,1)
plt.hist2d(N/2*adj.reshape(-1),B.reshape(-1),bins=(np.arange(10)-5+0.5,np.pi*(np.arange(100)-50+0.5)/50),density=True)
plt.xlabel(r'$NJ_{jk}/J$')
plt.ylabel(r'$\theta_j-\phi_k$')
plt.colorbar()

plt.subplot(1,3,2)
plt.plot(dt*np.arange(len(r)),r)
plt.xscale('log')
plt.yscale('log')
plt.xlabel('$t$')
plt.ylabel('$r$')

plt.subplot(1,3,3)
order=np.argsort(omega)
plt.scatter(omega,np.mod(theta+np.pi,2*np.pi)-np.pi,s=1)
plt.xlim(np.median(omega)-5,np.median(omega)+5)
plt.xlabel('$\omega_i$')
plt.ylabel(r'$\theta_i$')

plt.tight_layout()
plt.show()
# Out:
# <>:39: SyntaxWarning: invalid escape sequence '\o'
# <>:39: SyntaxWarning: invalid escape sequence '\o'
# /tmp/ipykernel_1616876/3843094306.py:39: SyntaxWarning: invalid escape sequence '\o'
#   plt.xlabel('$\omega_i$')
# ./kuramoto -g 3 -N 5000 -K 6 -c 1.000000 -t 0.000000 -d 0.100000 -s 1 -nv data/newtest2
#
# runtime: 68.505410

# %%
filebase='data/newtest3'
file=open(filebase+'.out')
lines=file.readlines()
N,K,t1,dt,c,seed=np.array(lines[0].split(),dtype=np.float64)
N=int(N)
K=int(K)
print(lines[1])
print(lines[-1])
file.close()

omega=np.fromfile(filebase+'frequencies.dat',dtype=np.float32)
N=len(omega)
thetas=np.unwrap(np.fromfile(filebase+'thetas.dat',dtype=np.float32).reshape((-1,N)),axis=0)
theta=np.fromfile(filebase+'fs.dat',dtype=np.float32)[:N]
r=np.fromfile(filebase+'order.dat',dtype=np.float32)
adj=np.fromfile(filebase+'adj.dat',dtype=np.float32).reshape((N,N))
coupling=np.fromfile(filebase+'fs.dat',dtype=np.float32)[N+2:]
B=np.mod(theta[:,np.newaxis]-np.arctan2(coupling[1::2],coupling[::2])[np.newaxis,:]+np.pi,2*np.pi)-np.pi


plt.subplots(1,3,figsize=(12,3))
plt.subplot(1,3,1)
plt.hist2d(N/2*adj.reshape(-1),B.reshape(-1),bins=(np.arange(100)-50+0.5,np.pi*(np.arange(100)-50+0.5)/50),density=True)
plt.xlabel(r'$NJ_{jk}/J$')
plt.ylabel(r'$\theta_j-\phi_k$')
plt.colorbar()

plt.subplot(1,3,2)
plt.plot(dt*np.arange(len(r)),r)
plt.xscale('log')
plt.yscale('log')
plt.xlabel('$t$')
plt.ylabel('$r$')

plt.subplot(1,3,3)
order=np.argsort(omega)
plt.scatter(omega,np.mod(theta+np.pi,2*np.pi)-np.pi,s=1)
plt.xlim(np.median(omega)-5,np.median(omega)+5)
plt.xlabel('$\omega_i$')
plt.ylabel(r'$\theta_i$')

plt.tight_layout()
plt.show()
# Out:
# <>:39: SyntaxWarning: invalid escape sequence '\o'
# <>:39: SyntaxWarning: invalid escape sequence '\o'
# /tmp/ipykernel_1616876/972639560.py:39: SyntaxWarning: invalid escape sequence '\o'
#   plt.xlabel('$\omega_i$')
# ./kuramoto -g 3 -N 5000 -K 5000 -c 1.000000 -t 0.000000 -d 0.100000 -s 1 -nv data/newtest3
#
# Using random adjacency matrix

# %%
filebase='data/newtest4'
file=open(filebase+'.out')
lines=file.readlines()
N,K,t1,dt,c,seed=np.array(lines[0].split(),dtype=np.float64)
N=int(N)
K=int(K)
print(lines[1])
print(lines[-1])
file.close()

omega=np.fromfile(filebase+'frequencies.dat',dtype=np.float32)
N=len(omega)
thetas=np.unwrap(np.fromfile(filebase+'thetas.dat',dtype=np.float32).reshape((-1,N)),axis=0)
theta=np.fromfile(filebase+'fs.dat',dtype=np.float32)[:N]
r=np.fromfile(filebase+'order.dat',dtype=np.float32)
adj=np.fromfile(filebase+'adj.dat',dtype=np.float32).reshape((N,N))
coupling=np.fromfile(filebase+'fs.dat',dtype=np.float32)[N+2:]
B=np.mod(theta[:,np.newaxis]-np.arctan2(coupling[1::2],coupling[::2])[np.newaxis,:]+np.pi,2*np.pi)-np.pi


plt.subplots(1,3,figsize=(12,3))
plt.subplot(1,3,1)
plt.hist2d(N/2*adj.reshape(-1),B.reshape(-1),bins=(np.arange(100)-50+0.5,np.pi*(np.arange(100)-50+0.5)/50),density=True)
plt.xlabel(r'$NJ_{jk}/J$')
plt.ylabel(r'$\theta_j-\phi_k$')
plt.colorbar()

plt.subplot(1,3,2)
plt.plot(dt*np.arange(len(r)),r)
plt.xscale('log')
plt.yscale('log')
plt.xlabel('$t$')
plt.ylabel('$r$')

plt.subplot(1,3,3)
order=np.argsort(omega)
plt.scatter(omega,np.mod(theta+np.pi,2*np.pi)-np.pi,s=1)
plt.xlim(np.median(omega)-5,np.median(omega)+5)
plt.xlabel('$\omega_i$')
plt.ylabel(r'$\theta_i$')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Scaling of the maximum frequency $\omega_M$

# %%
def func_cauchy(omega,N):
    return N/(np.pi*(1+omega**2))*(1/np.pi*np.arctan(omega)+0.5)**(N-1)
def func_cauchy2(omega,N):
    return N*omega/(np.pi*(1+omega**2))*(1/np.pi*np.arctan(omega)+0.5)**(N-1)
    
N=1000000
omegamax=100*N
omegamin=0
num=100000
omega=omegamax+(omegamin-omegamax)*np.arange(num)/num
a=func_cauchy(omega,N)
a2=func_cauchy2(omega,N)
plt.plot(omega,a)
plt.show()
plt.plot(omega,a2)
plt.show()
print(np.sum(a*(omegamax-omegamin)/num))
print(np.sum(a2*(omegamax-omegamin)/num))
print(np.sum(a2*(omegamax-omegamin)/num)/N)
# Out:
# 0.9968219777185505
# 1647530.7356379488
# 1.647530735637949

# %%
N=10000
Ns=[1000,10000,100000,1000000]
Ns=np.arange(10000,10000000,10000)
test=[]
for N in Ns:
    omegamax=100*N
    omegamin=0
    omega=omegamax+(omegamin-omegamax)*np.arange(num)/num
    a2=func_cauchy2(omega,N)
    test=test+[np.sum(a2*(omegamax-omegamin)/num)]
plt.plot(Ns,test)

# %%
def func_normal(omega,N):
    return N*np.exp(-omega**2/2)/(2*np.pi)**0.5*(0.5+0.5*erf(omega/2**0.5))**(N-1)
def func_normal2(omega,N):
    return N*omega*np.exp(-omega**2/2)/(2*np.pi)**0.5*(0.5+0.5*erf(omega/2**0.5))**(N-1)

N=10000000
omegamax=10
omegamin=0
num=100000
omega=omegamax+(omegamin-omegamax)*np.arange(num)/num
a=func_normal(omega,N)
a2=func_normal2(omega,N)
plt.plot(omega,a)
plt.show()
plt.plot(omega,a2)
plt.show()
print(np.sum(a*(omegamax-omegamin)/num))
print(np.sum(a2*(omegamax-omegamin)/num))
print(np.sum(a2*(omegamax-omegamin)/num)/(np.log(N)**0.5))
# Out:
# 1.0000000000059996
# 5.300954010204268
# 1.3203746328990722

# %%
Ns=[1000,10000,100000,1000000]
Ns=np.arange(10000,10000000,10000)
test=[]
for N in Ns:
    a2=func_normal2(omega,N)
    test=test+[np.sum(a2*(omegamax-omegamin)/num)]
plt.plot(Ns,test)
plt.xscale('log')
